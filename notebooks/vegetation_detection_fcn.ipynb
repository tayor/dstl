# %% [markdown]
# # Vegetation detection

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../common/")

import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
from data_utils import TRAIN_IMAGE_IDS, LABELS
from image_utils import get_image_data, TRAIN_DATA, TRAIN_LABEL_TILES, get_image_tile_data, normalize
from visu_utils import display_img_1b, display_labels

# %%
import cv2

# %% [markdown]
# ### Input data
#
# Images of shape (512, 512, 17)

# %%
from fcn_kentow import fcn_zero

# %%
for i, l in enumerate(LABELS):
    print i, l
# Out:
# 0 None
# 1 Buildings
# 2 Misc. Manmade structures
# 3 Road
# 4 Track
# 5 Trees
# 6 Crops
# 7 Waterway
# 8 Standing water
# 9 Vehicle Large
# 10 Vehicle Small

# %%
# RESIZE_TILES = False
# # tile_size = (512, 512)
# tile_size = (128, 128)
# n_channels = 17
# model = unet_zero(len(LABELS)-1, n_channels, *tile_size)

# %%
RESIZE_TILES = True
tile_size = (128, 128)
# channels = np.array(range(11))
channels = np.array([0, 1, 2, 3, 5, 6])
n_channels = len(channels)
# labels = np.array(range(len(LABELS)))
labels = np.array([0, 5, 6])
n_labels = len(labels)

model = fcn_zero(n_labels, n_channels, *tile_size)

# %%
channels, labels
# Out:
# (array([0, 1, 2, 3, 5, 6]), array([0, 5, 6]))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_13 (InputLayer)            (None, 6, 128, 128)   0
# ____________________________________________________________________________________________________
# convolution2d_154 (Convolution2D (None, 64, 128, 128)  3520        input_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_155 (Convolution2D (None, 64, 128, 128)  36928       convolution2d_154[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_60 (MaxPooling2D)   (None, 64, 64, 64)    0           convolution2d_155[0][0]
# ____________________________________________________________________________________________________
# convolution2d_156 (Convolution2D (None, 128, 64, 64)   73856       maxpooling2d_60[0][0]
# ____________________________________________________________________________________________________
# convolution2d_157 (Convolution2D (None, 128, 64, 64)   147584      convolution2d_156[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_61 (MaxPooling2D)   (None, 128, 32, 32)   0           convolution2d_157[0][0]
# ____________________________________________________________________________________________________
# convolution2d_158 (Convolution2D (None, 256, 32, 32)   295168      maxpooling2d_61[0][0]
# ____________________________________________________________________________________________________
# convolution2d_159 (Convolution2D (None, 256, 32, 32)   590080      convolution2d_158[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_62 (MaxPooling2D)   (None, 256, 16, 16)   0           convolution2d_159[0][0]
# ____________________________________________________________________________________________________
# convolution2d_161 (Convolution2D (None, 512, 16, 16)   1180160     maxpooling2d_62[0][0]
# ____________________________________________________________________________________________________
# convolution2d_162 (Convolution2D (None, 512, 16, 16)   2359808     convolution2d_161[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_63 (MaxPooling2D)   (None, 512, 8, 8)     0           convolution2d_162[0][0]
# ____________________________________________________________________________________________________
# convolution2d_164 (Convolution2D (None, 512, 8, 8)     2359808     maxpooling2d_63[0][0]
# ____________________________________________________________________________________________________
# convolution2d_165 (Convolution2D (None, 512, 8, 8)     2359808     convolution2d_164[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_64 (MaxPooling2D)   (None, 512, 4, 4)     0           convolution2d_165[0][0]
# ____________________________________________________________________________________________________
# convolution2d_163 (Convolution2D (None, 3, 8, 8)       1539        maxpooling2d_63[0][0]
# ____________________________________________________________________________________________________
# convolution2d_166 (Convolution2D (None, 3, 4, 4)       1539        maxpooling2d_64[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_30 (Deconvolutio (None, 3, 18, 18)     147         convolution2d_163[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_31 (Deconvolutio (None, 3, 20, 20)     579         convolution2d_166[0][0]
# ____________________________________________________________________________________________________
# convolution2d_160 (Convolution2D (None, 3, 16, 16)     771         maxpooling2d_62[0][0]
# ____________________________________________________________________________________________________
# cropping2d_29 (Cropping2D)       (None, 3, 16, 16)     0           deconvolution2d_30[0][0]
# ____________________________________________________________________________________________________
# cropping2d_30 (Cropping2D)       (None, 3, 16, 16)     0           deconvolution2d_31[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                 (None, 3, 16, 16)     0           convolution2d_160[0][0]
#                                                                    cropping2d_29[0][0]
#                                                                    cropping2d_30[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_32 (Deconvolutio (None, 3, 136, 136)   2307        merge_12[0][0]
# ____________________________________________________________________________________________________
# cropping2d_31 (Cropping2D)       (None, 3, 128, 128)   0           deconvolution2d_32[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 49152)         0           cropping2d_31[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 49152)         0           flatten_2[0][0]
# ____________________________________________________________________________________________________
# reshape_5 (Reshape)              (None, 3, 128, 128)   0           activation_5[0][0]
# ====================================================================================================
# Total params: 9,413,602
# Trainable params: 9,413,602
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
import os
from keras.optimizers import Adam, Nadam, SGD
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from metrics import jaccard_coef, jaccard_coef_int

# %%
from glob import glob
all_train_tiles = glob(os.path.join(TRAIN_DATA, "*.tif"))
all_train_tiles = np.array([s[len(TRAIN_DATA)+1:] for s in all_train_tiles])

# %%
all_train_tiles[0]
# Out:
# '6010_1_2_0_0.tif'

# %%
from sklearn.model_selection import train_test_split 

# TRAIN ON N TILES
n_tiles = 256
if n_tiles > 0:
    train_tiles, val_tiles = train_test_split(all_train_tiles[:n_tiles], test_size=0.3)
else:
    train_tiles, val_tiles = train_test_split(all_train_tiles, test_size=0.3)
    
print len(train_tiles), len(val_tiles)
# Out:
# 179 77

# %%
def normalize_image(img_data, max_value=1.0):
    if RESIZE_TILES:
        out = cv2.resize(img_data, dsize=tile_size, interpolation=cv2.INTER_CUBIC).astype(np.float32)
        if len(out.shape) == 2:
            out = out[:, :, None]
    else:
        out = img_data.astype(np.float32)

    if max_value > 1.0:  
        out = normalize(out, 0.01, 99.9)        
    
    out = out.transpose([2,0,1])
    return out


def make_ratios_vegetation(img_17b):
    """
        Method creates an image of all possible band ratios
        
        - panchromatic[0] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
        - panchromatic[0] / MS[4] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[1] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[2] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[6] / MS[4] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[6] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[7] / MS[4] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[7] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[7] / MS[10:17] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[8] / MS[4] = Trees, Crops, Misc manmade structures (of trees) 
        - MS[8:17] / MS[5] = Trees, Crops, Misc manmade structures (of trees) 
    """
    h, w, n = img_17b.shape
    
    out_n = 23
    out = np.zeros((h, w, out_n), dtype=np.float32)
    def _ratio(i, j):
        return img_17b[:,:,i] / (img_17b[:,:,j] + 0.00001)
        
    out[:,:,0] = _ratio(0, 5)
    out[:,:,1] = _ratio(0, 4)
    out[:,:,2] = _ratio(1, 5)
    out[:,:,3] = _ratio(2, 5)
    out[:,:,4] = _ratio(6, 4)
    out[:,:,5] = _ratio(6, 5)
    out[:,:,6] = _ratio(7, 4)
    out[:,:,7] = _ratio(7, 5)
    out[:,:,8] = _ratio(7, 10)
    out[:,:,9] = _ratio(7, 11)
    out[:,:,10] = _ratio(7, 12)
    out[:,:,11] = _ratio(7, 13)
    out[:,:,12] = _ratio(7, 14)
    out[:,:,13] = _ratio(7, 15)
    out[:,:,14] = _ratio(7, 16)
    out[:,:,15] = _ratio(8, 4)
    out[:,:,16] = _ratio(9, 5)
    out[:,:,17] = _ratio(10, 5)
    out[:,:,18] = _ratio(11, 5)
    out[:,:,19] = _ratio(12, 5)
    out[:,:,20] = _ratio(13, 5)
    out[:,:,21] = _ratio(14, 5)
    out[:,:,22] = _ratio(15, 5)
    return out


def generate_images(train_tiles, batch_size):
    while True:
        n = len(train_tiles)
        n_batches = n // batch_size
        random_indices = np.arange(n)
        np.random.shuffle(random_indices)
        for i in range(n_batches):
            end = min((i+1)*batch_size, n) 
            batch_indices = random_indices[batch_size*i:end]
            X = np.zeros((batch_size, n_channels)+tile_size, dtype=np.float32)
            Y = np.zeros((batch_size, n_labels)+tile_size, dtype=np.float32)
            for j, tile_id in enumerate(train_tiles[batch_indices]):
                x = get_image_tile_data(os.path.join(TRAIN_DATA,tile_id))
                y = get_image_tile_data(os.path.join(TRAIN_LABEL_TILES,tile_id))

                x = make_ratios_vegetation(x)
                
                if n_labels < len(LABELS) - 1:
                    y = y[:,:,labels]
                if n_channels < 17:
                    x = x[:,:,channels]

                x = normalize_image(x, 2.0**10)
                y = normalize_image(y)     
                
                X[j,:,:,:] = x
                Y[j,:,:,:] = y 
                
            yield (X, Y)

# %%
batch_size = 5
for X, Y in generate_images(train_tiles, batch_size):
    print X.shape, Y.shape
    print X.min(), X.max(), Y.min(), Y.max()
    
    for i in range(batch_size):
        plt.figure(figsize=(14, 6))    
        plt.subplot(261)
        display_img_1b(X[i,1,:,:])
        for j in range(n_labels):
            plt.subplot(2,6,j+2)
            display_img_1b(Y[i,j,:,:])

    break
# Out:
# (5L, 6L, 128L, 128L) (5L, 3L, 128L, 128L)
# 0.0 1.0 0.0 1.0

# %%
if not os.path.exists('weights'):
    os.mkdir('weights')
    
model_checkpoint = ModelCheckpoint('weights/fcn_zero.h5', monitor='loss', save_best_only=True)
earlyStop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0)

# LearningRateScheduler

# %%
# model.compile(optimizer=Nadam(lr=0.01), loss='binary_crossentropy', metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
# model.compile(optimizer=Nadam(lr=0.001), loss='categorical_crossentropy', metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])
# model.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy', metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])

# sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=[jaccard_coef, jaccard_coef_int, 'accuracy'])

# %% [markdown]
# We have 25 images splitted into 64 tiles. It gives 1600 tiles to train on.
# Train/test split with test size 0.3 gives: 1120 and 480 number of tiles.
# Assembling 32 tiles in a batch, we obtain 35 batches for training tiles and 15 batches for validation.

# %%
# from keras.callbacks import RemoteMonitor
# rmon = RemoteMonitor(root='http://localhost:9000', path='/publish/epoch/end/', field='data', headers={'Content-Type': 'application/json', 'Accept': 'application/json'})

# %%
foo = lambda x: max(x // 10, min(batch_size * 10, x))

batch_size = 16
samples_per_epoch = foo(len(train_tiles))
nb_val_samples = foo(len(val_tiles))


print batch_size, samples_per_epoch, nb_val_samples

history = model.fit_generator(
    generate_images(train_tiles, batch_size),
    samples_per_epoch=samples_per_epoch, 
    nb_epoch=20,
    validation_data=generate_images(val_tiles, batch_size),
    nb_val_samples=nb_val_samples,
    callbacks=[model_checkpoint],
    verbose=2
)
# Out:
# 16 160 77
# Epoch 1/20
# 32s - loss: 203.7968 - jaccard_coef: 1.3549e-05 - jaccard_coef_int: 6.2382e-14 - acc: 0.0490 - val_loss: 203.3604 - val_jaccard_coef: 1.3527e-05 - val_jaccard_coef_int: 6.2181e-14 - val_acc: 0.0503
# Epoch 2/20
# 23s - loss: 204.5242 - jaccard_coef: 1.3516e-05 - jaccard_coef_int: 6.2084e-14 - acc: 0.0568 - val_loss: 202.7752 - val_jaccard_coef: 1.3500e-05 - val_jaccard_coef_int: 6.1946e-14 - val_acc: 0.0467
# Epoch 3/20
# 23s - loss: 203.7038 - jaccard_coef: 1.3485e-05 - jaccard_coef_int: 6.1809e-14 - acc: 0.0132 - val_loss: 202.8613 - val_jaccard_coef: 1.3475e-05 - val_jaccard_coef_int: 6.1711e-14 - val_acc: 0.0090
# Epoch 4/20
# 23s - loss: 203.5799 - jaccard_coef: 1.3474e-05 - jaccard_coef_int: 6.1705e-14 - acc: 0.0097 - val_loss: 202.9286 - val_jaccard_coef: 1.3477e-05 - val_jaccard_coef_int: 6.1733e-14 - val_acc: 0.0104
# Epoch 5/20
# 23s - loss: 204.4813 - jaccard_coef: 1.3482e-05 - jaccard_coef_int: 6.1779e-14 - acc: 0.0089 - val_loss: 203.0708 - val_jaccard_coef: 1.3485e-05 - val_jaccard_coef_int: 6.1812e-14 - val_acc: 0.0088
# Epoch 6/20
# 23s - loss: 203.7666 - jaccard_coef: 1.3484e-05 - jaccard_coef_int: 6.1802e-14 - acc: 0.0085 - val_loss: 203.6195 - val_jaccard_coef: 1.3475e-05 - val_jaccard_coef_int: 6.1715e-14 - val_acc: 0.0097
# Epoch 7/20
# 23s - loss: 204.2991 - jaccard_coef: 1.3462e-05 - jaccard_coef_int: 6.1603e-14 - acc: 0.0090 - val_loss: 202.6998 - val_jaccard_coef: 1.3447e-05 - val_jaccard_coef_int: 6.1467e-14 - val_acc: 0.0097
# Epoch 8/20
# 22s - loss: 203.7029 - jaccard_coef: 1.3439e-05 - jaccard_coef_int: 6.1393e-14 - acc: 0.0104 - val_loss: 203.3857 - val_jaccard_coef: 1.3432e-05 - val_jaccard_coef_int: 6.1338e-14 - val_acc: 0.0109
# Epoch 9/20
# 23s - loss: 204.2473 - jaccard_coef: 1.3428e-05 - jaccard_coef_int: 6.1298e-14 - acc: 0.0107 - val_loss: 203.3476 - val_jaccard_coef: 1.3423e-05 - val_jaccard_coef_int: 6.1255e-14 - val_acc: 0.0122
# Epoch 10/20
# 23s - loss: 203.8071 - jaccard_coef: 1.3414e-05 - jaccard_coef_int: 6.1172e-14 - acc: 0.0109 - val_loss: 202.8077 - val_jaccard_coef: 1.3398e-05 - val_jaccard_coef_int: 6.1035e-14 - val_acc: 0.0111
# Epoch 11/20
# 23s - loss: 204.0249 - jaccard_coef: 1.3389e-05 - jaccard_coef_int: 6.0948e-14 - acc: 0.0105 - val_loss: 202.9707 - val_jaccard_coef: 1.3379e-05 - val_jaccard_coef_int: 6.0867e-14 - val_acc: 0.0450
# Epoch 12/20
# 23s - loss: 204.0593 - jaccard_coef: 1.3382e-05 - jaccard_coef_int: 6.0891e-14 - acc: 0.0613 - val_loss: 202.9162 - val_jaccard_coef: 1.3384e-05 - val_jaccard_coef_int: 6.0913e-14 - val_acc: 0.0781
# Epoch 13/20
# 22s - loss: 203.7854 - jaccard_coef: 1.3380e-05 - jaccard_coef_int: 6.0872e-14 - acc: 0.1065 - val_loss: 202.8488 - val_jaccard_coef: 1.3377e-05 - val_jaccard_coef_int: 6.0848e-14 - val_acc: 0.1097
# Epoch 14/20
# 22s - loss: 204.0814 - jaccard_coef: 1.3382e-05 - jaccard_coef_int: 6.0890e-14 - acc: 0.0910 - val_loss: 202.9337 - val_jaccard_coef: 1.3384e-05 - val_jaccard_coef_int: 6.0910e-14 - val_acc: 0.0791
# Epoch 15/20
# 22s - loss: 203.9245 - jaccard_coef: 1.3387e-05 - jaccard_coef_int: 6.0934e-14 - acc: 0.0780 - val_loss: 203.0520 - val_jaccard_coef: 1.3387e-05 - val_jaccard_coef_int: 6.0940e-14 - val_acc: 0.0768
# Epoch 16/20
# 22s - loss: 204.0807 - jaccard_coef: 1.3387e-05 - jaccard_coef_int: 6.0929e-14 - acc: 0.0912 - val_loss: 202.3873 - val_jaccard_coef: 1.3385e-05 - val_jaccard_coef_int: 6.0925e-14 - val_acc: 0.1118
# Epoch 17/20
# 22s - loss: 203.9321 - jaccard_coef: 1.3390e-05 - jaccard_coef_int: 6.0958e-14 - acc: 0.1098 - val_loss: 203.0316 - val_jaccard_coef: 1.3394e-05 - val_jaccard_coef_int: 6.1000e-14 - val_acc: 0.1104
# Epoch 18/20
# 22s - loss: 204.0375 - jaccard_coef: 1.3395e-05 - jaccard_coef_int: 6.1005e-14 - acc: 0.0934 - val_loss: 203.0307 - val_jaccard_coef: 1.3388e-05 - val_jaccard_coef_int: 6.0953e-14 - val_acc: 0.0776
# Epoch 19/20
# 23s - loss: 203.9626 - jaccard_coef: 1.3384e-05 - jaccard_coef_int: 6.0903e-14 - acc: 0.0776 - val_loss: 203.0741 - val_jaccard_coef: 1.3379e-05 - val_jaccard_coef_int: 6.0866e-14 - val_acc: 0.1109
# Epoch 20/20
# 22s - loss: 204.1269 - jaccard_coef: 1.3380e-05 - jaccard_coef_int: 6.0874e-14 - acc: 0.1111 - val_loss: 202.7891 - val_jaccard_coef: 1.3380e-05 - val_jaccard_coef_int: 6.0877e-14 - val_acc: 0.1114

# %%
plt.plot(history.history['val_jaccard_coef_int'])
plt.ylabel('Jaccard coeff integer')
# plt.plot(history.history['val_jaccard_coef'])
# plt.ylabel('Jaccard coeff')
plt.xlabel('Training iterations')
plt.legend(['Testing'], loc='upper left')
plt.show()

# %%
def _plot(X, Y, Y_pred, i, c=1):
    plt.figure(figsize=(12,6))
    plt.subplot(131)
    display_img_1b(X[i,0,:,:])
    plt.subplot(132)
    display_img_1b(Y[i,c,:,:])
    plt.subplot(133)
    display_img_1b(Y_pred[i,c,:,:])

# %%
batch_size = 5

for X, Y in generate_images(train_tiles, batch_size):
    Y_pred = model.predict_on_batch(X)
    print Y_pred.shape, Y_pred.min(), Y_pred.max()

    for i in range(batch_size):
        _plot(X, Y, Y_pred, i)

#     print jaccard_coef(Y, Y_pred), jaccard_coef_int(Y, Y_pred)
    break
# Out:
# (5L, 3L, 128L, 128L) 1.96654e-05 2.1167e-05

# %%
_plot(X, Y, Y_pred, 0, 0)

# %%
y = Y_pred[0,1,:,:]
print y.min(), y.max()
# Out:
# 2.11063e-12 0.000444466
